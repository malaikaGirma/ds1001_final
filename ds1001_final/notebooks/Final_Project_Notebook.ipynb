# %% [markdown]
# # Final Project Notebook
#
# Use the follow cells prompts to complete the final project for the course. Everything you need should be present in this notebook or previous notebooks we've used in class. You can work together as needed.
#
#  - You will need to name your own dataset and use that name throughout
#  - There are sections where you need to make changes the code and insert new code this will be noted in the code provided
#  - You may get frustrated along the way, this is totally normal, just remember even small changes to the code make a huge difference.

# %% [markdown]
# ## Question Fork the Repository
# i. Include a screenshot of the forked repo in your GitHub account
#
# To fork the repository:
# 1. Go to https://github.com/NovaVolunteer/ds1001_final
# 2. Click the "Fork" button in the top right corner
# 3. The repo will be forked to your GitHub account
# 4. Take a screenshot of your forked repository

# %% [markdown]
# ### You should now be able to open your cloned repo in google collab, use the code below.
#
# ### It's very helpful to have the variable inspector open while you go through this process. To do so go to tools>command palette>show variable inspector
#
# ### It's also helpful to open up the folder tree on the left menu bar. Just click on the folder icon and then the ds1001_final folder. The data is located in the data folder in the processed sub-folder.

# %%
#!git clone "https://github.com/username/repository.git"
# This script clones a GitHub repository using Git command line tool. 
# Insert the path to your desired repository in place of the URL.
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %% [markdown]
# ## Systems

# %%
# Activate the finalproj environment
# !source ds1001_final/ds1001_final/finalproj/bin/activate
# Out:
# /bin/bash: line 1: ds1001_final/ds1001_final/finalproj/bin/activate: No such file or directory

# %%
### You can use this command to list all the packages in your environment
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.11.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.0.5
# attrs                     25.4.0
# Automat                   25.4.16
# babel                     2.17.0
# beautifulsoup4            4.14.2
# bleach                    6.3.0
# certifi                   2025.11.12
# cffi                      2.0.0
# charset-normalizer        3.4.4
# comm                      0.2.3
# constantly                23.10.4
# contourpy                 1.3.3
# cryptography              47.0.0
# cssselect                 1.4.0
# cycler                    0.12.1
# debugpy                   1.8.17
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fairlearn                 0.13.0
# fastjsonschema            2.21.2
# filelock                  3.29.0
# fonttools                 4.60.1
# fqdn                      1.5.1
# greenlet                  3.4.0
# h11                       0.16.0
# happybase                 1.3.0
# httpcore                  1.0.9
# httpx                     0.28.1
# hyperlink                 21.0.0
# idna                      3.11
# importlib_resources       7.1.0
# Incremental               24.11.0
# ipykernel                 7.1.0
# ipython                   9.7.0
# ipython_pygments_lexers   1.1.1
# ipywidgets                8.1.8
# isoduration               20.11.0
# itemadapter               0.13.1
# itemloaders               1.4.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# jmespath                  1.1.0
# joblib                    1.5.2
# json5                     0.12.1
# jsonpointer               3.0.0
# jsonschema                4.25.1
# jsonschema-specifications 2025.9.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.5.0
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# jupyterlab_widgets        3.0.16
# kiwisolver                1.4.9
# lark                      1.3.1
# logzero                   1.7.0
# lxml                      6.1.0
# MarkupSafe                3.0.3
# matplotlib                3.10.7
# matplotlib-inline         0.2.1
# mice                      0.1.31
# mistune                   3.1.4
# narwhals                  2.12.0
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.5.0
# notebook_shim             0.2.4
# numpy                     2.3.5
# packaging                 25.0
# pandas                    2.3.3
# pandocfilters             1.5.1
# parsel                    1.11.0
# parso                     0.8.5
# pexpect                   4.9.0
# pillow                    12.0.0
# pip                       23.2.1
# platformdirs              4.5.0
# ply                       3.11
# prometheus_client         0.23.1
# prompt_toolkit            3.0.52
# Protego                   0.6.0
# psutil                    7.1.3
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pyasn1                    0.6.3
# pyasn1_modules            0.4.2
# pycparser                 2.23
# PyDispatcher              2.0.7
# Pygments                  2.19.2
# PyMySQL                   1.1.2
# pyOpenSSL                 26.1.0
# pyparsing                 3.2.5
# pyquery                   2.0.1
# python-dateutil           2.9.0.post0
# python-json-logger        4.0.0
# pytz                      2025.2
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# queuelib                  1.9.0
# redis                     7.4.0
# referencing               0.37.0
# requests                  2.32.5
# requests-file             3.0.1
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.29.0
# scikit-learn              1.7.2
# scipy                     1.15.3
# Scrapy                    2.15.1
# scrapy-redis              0.9.1
# scrapyd                   1.6.0
# scrapyd-client            2.0.3
# seaborn                   0.13.2
# Send2Trash                1.8.3
# service-identity          24.2.0
# setuptools                80.9.0
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.8
# SQLAlchemy                2.0.49
# stack-data                0.6.3
# terminado                 0.18.1
# threadpoolctl             3.6.0
# thriftpy2                 0.6.0
# tinycss2                  1.4.0
# tld                       0.13.2
# tldextract                5.3.1
# tornado                   6.5.2
# traitlets                 5.14.3
# Twisted                   25.5.0
# typing_extensions         4.15.0
# tzdata                    2025.2
# uberegg                   0.1.1
# uri-template              1.3.0
# urllib3                   2.5.0
# w3lib                     2.4.1
# wcwidth                   0.2.14
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# widgetsnbextension        4.0.15
# XX                        3.3.2
# zope.interface            8.3
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install "XX"

#You'll likely need to install the fairlearn packages, if not already installed.
#Are there additional packages to install? (Cross check with the list above to 
# ensure all packages are installed)
# Out:
# Requirement already satisfied: XX in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (3.3.2)
# Requirement already satisfied: scrapy in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (2.15.1)
# Requirement already satisfied: scrapyd in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (1.6.0)
# Requirement already satisfied: scrapyd-client in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (2.0.3)
# Requirement already satisfied: scrapy-redis in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (0.9.1)
# Requirement already satisfied: pyquery in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (2.0.1)
# Requirement already satisfied: redis in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (7.4.0)
# Requirement already satisfied: requests in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (2.32.5)
# Requirement already satisfied: pymysql in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (1.1.2)
# Requirement already satisfied: sqlalchemy in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (2.0.49)
# Requirement already satisfied: logzero in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (1.7.0)
# Requirement already satisfied: happybase in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (1.3.0)
# Requirement already satisfied: tld in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from XX) (0.13.2)
# Requirement already satisfied: six in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from happybase->XX) (1.17.0)
# Requirement already satisfied: thriftpy2>=0.4 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from happybase->XX) (0.6.0)
# Requirement already satisfied: importlib-resources in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from happybase->XX) (7.1.0)
# Requirement already satisfied: lxml>=2.1 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from pyquery->XX) (6.1.0)
# Requirement already satisfied: cssselect>=1.2.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from pyquery->XX) (1.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from requests->XX) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from requests->XX) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from requests->XX) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from requests->XX) (2025.11.12)
# Requirement already satisfied: cryptography>=37.0.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (47.0.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (0.7.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (0.13.1)
# Requirement already satisfied: itemloaders>=1.0.1 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (1.4.0)
# Requirement already satisfied: packaging in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (25.0)
# Requirement already satisfied: parsel>=1.5.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (1.11.0)
# Requirement already satisfied: protego>=0.1.15 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (0.6.0)
# Requirement already satisfied: pydispatcher>=2.0.5 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (2.0.7)
# Requirement already satisfied: pyopenssl>=22.0.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (26.1.0)
# Requirement already satisfied: queuelib>=1.4.2 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (1.9.0)
# Requirement already satisfied: service-identity>=18.1.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (24.2.0)
# Requirement already satisfied: tldextract in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (5.3.1)
# Requirement already satisfied: twisted<=25.5.0,>=21.7.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (25.5.0)
# Requirement already satisfied: w3lib>=1.17.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (2.4.1)
# Requirement already satisfied: zope-interface>=5.1.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapy->XX) (8.3)
# Requirement already satisfied: setuptools<81 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapyd->XX) (80.9.0)
# Requirement already satisfied: pip in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapyd-client->XX) (23.2.1)
# Requirement already satisfied: uberegg>=0.1.1 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from scrapyd-client->XX) (0.1.1)
# Requirement already satisfied: greenlet>=1 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from sqlalchemy->XX) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from sqlalchemy->XX) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from cryptography>=37.0.0->scrapy->XX) (2.0.0)
# Requirement already satisfied: jmespath>=0.9.5 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from itemloaders>=1.0.1->scrapy->XX) (1.1.0)
# Requirement already satisfied: attrs>=19.1.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from service-identity>=18.1.0->scrapy->XX) (25.4.0)
# Requirement already satisfied: pyasn1 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from service-identity>=18.1.0->scrapy->XX) (0.6.3)
# Requirement already satisfied: pyasn1-modules in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from service-identity>=18.1.0->scrapy->XX) (0.4.2)
# Requirement already satisfied: ply<4.0,>=3.4 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from thriftpy2>=0.4->happybase->XX) (3.11)
# Requirement already satisfied: automat>=24.8.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (25.4.16)
# Requirement already satisfied: constantly>=15.1 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (24.11.0)
# Requirement already satisfied: requests-file>=1.4 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from tldextract->scrapy->XX) (3.0.1)
# Requirement already satisfied: filelock>=3.0.8 in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from tldextract->scrapy->XX) (3.29.0)
# Requirement already satisfied: pycparser in /workspaces/ds1001_final/myenv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=37.0.0->scrapy->XX) (2.23)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Check !pip list again to confirm installations

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import fairlearn.metrics
from fairlearn.metrics import MetricFrame
from fairlearn.metrics import count, true_positive_rate, false_positive_rate, selection_rate, demographic_parity_ratio

# %% [markdown]
# ## Design: Data prep and exploration

# %%
data = pd.read_csv('../data/processed/bank_final.csv') # the data is the data folder, 
#you'll need to use the correct path to the dataset. 

# How many rows are in the dataframe? How many columns?
data.shape
# Out:
# (43628, 13)

# %%
# Explore the variables a bit more, create histograms for the numerics values and bar charts for the categorical.
# Histograms for numeric variables
numeric_columns = data.select_dtypes(include=['number']).columns
for col in numeric_columns: 
    plt.figure(figsize=(10, 6))
    sns.histplot(data[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.show()

# %%
# Bar charts for categorical variables
categorical_columns = data.select_dtypes(include=['object', 'category']).columns
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=data[col])
    plt.title(f'Bar Chart of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# How many numeric columns are in the data set?
num_numeric_columns =data.select_dtypes(include=['number']).shape[1]
print(num_numeric_columns)
# Out:
# 5

# %%
# Normalization
scaler = MinMaxScaler()
data[data.select_dtypes(include=['number']).columns] = scaler.fit_transform(data.select_dtypes(include=['number']))

# %%
# Likely need to convert categorical columns to category dtype

for col in data.select_dtypes(include=['object']).columns:
    data[col] = data[col].astype('category')  

original_cols = data.shape[1]
print(original_cols)
# Out:
# 13

# %%
# Creating dummy variables, make sure the variables that need to be converted to dummies are categorical, not numeric.
# This might require you to convert some columns to categorical first using astype('category')

data = pd.get_dummies(data, drop_first=True)

# %%
# Display missing data using the isnull function, is there any missing data?
print(data.isnull().sum())
new_cols = data.shape[1]
print("Original columns:", original_cols)
print("New columns:", new_cols)
print("Columns added:", new_cols - original_cols)
# Out:
# age                    0
# balance                0
# duration               0
# contactndays           0
# signed up              0
# job_blue-collar        0
# job_entrepreneur       0
# job_housemaid          0
# job_management         0
# job_retired            0
# job_self-employed      0
# job_services           0
# job_student            0
# job_technician         0
# job_unemployed         0
# job_unknown            0
# marital_married        0
# marital_single         0
# education_secondary    0
# education_tertiary     0
# education_unknown      0
# race_black             0
# race_hispanic          0
# race_white             0
# default_yes            0
# housing_yes            0
# contact_telephone      0
# contact_unknown        0
# gender_m               0
# dtype: int64
# Original columns: 13
# New columns: 29
# Columns added: 16

# %%
# remove missing values if needed
data = data.dropna()

# %%
# Scatterplot between two continuous variables
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='balance', data=data)  # Replace 'Variable1' and 'Variable2' with your column names
plt.title('Age vs Account Balance Scatterplot')
plt.savefig('scatterplot.png')  # Save the scatterplot image
plt.show()

# %%
# Density chart of a continuous variable
plt.figure(figsize=(10, 6))
sns.kdeplot(data['balance'], fill=True)  # Replace 'ContinuousVariable' with your column name
plt.title('Density Chart of Account Balance')
plt.show()

# %%
#Correlation matrix, make sure to only include numeric variables
num_values = data.select_dtypes(include=['number'])
correlation_matrix = num_values.corr()
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Analytics: Build a model and Tune it for best Best Performance

# %%
# What is the ‘target’ of a model and what is the prevalence of the target in your dataset? Remember prevalence 
# is the proportion of records that take on the value of interest for the target variable, usually the positive class.
target_prevalence = data['signed up'].sum()  # Replace 'TargetVariable' with your target column name
print(f'Target Prevalence: {target_prevalence}')
# Out:
# Target Prevalence: 5074.0

# %%
# Divide the dataset into features and target
target = data['signed up']  # Replace 'TargetVariable' with your actual target column name and "xx" with your dataframe name
features = data.drop(columns=['signed up']) # Drop the target column from features
print(features)
# Out:
#             age   balance  duration  contactndays  job_blue-collar  \
# 0      0.324675  0.073384  0.046767      0.000000            False
# 1      0.727273  0.123091  0.051444      0.208716            False
# 2      0.194805  0.076190  0.078081      0.000000            False
# 3      0.246753  0.081283  0.052460      0.000000             True
# 4      0.155844  0.072812  0.014030      0.000000            False
# ...         ...       ...       ...           ...              ...
# 43623  0.116883  0.077452  0.044734      0.000000            False
# 43624  0.311688  0.077888  0.028264      0.000000             True
# 43625  0.142857  0.078078  0.039040      0.000000            False
# 43626  0.220779  0.084206  0.005287      0.000000            False
# 43627  0.311688  0.077252  0.078487      0.000000             True
#
#        job_entrepreneur  job_housemaid  job_management  job_retired  \
# 0                 False          False           False        False
# 1                 False          False           False         True
# 2                 False          False            True        False
# 3                 False          False           False        False
# 4                 False          False           False        False
# ...                 ...            ...             ...          ...
# 43623              True          False           False        False
# 43624             False          False           False        False
# 43625             False          False            True        False
# 43626             False          False            True        False
# 43627             False          False           False        False
#
#        job_self-employed  ...  education_tertiary  education_unknown  \
# 0                   True  ...                True              False
# 1                  False  ...               False              False
# 2                  False  ...                True              False
# 3                  False  ...               False              False
# 4                  False  ...                True              False
# ...                  ...  ...                 ...                ...
# 43623              False  ...                True              False
# 43624              False  ...               False              False
# 43625              False  ...                True              False
# 43626              False  ...                True              False
# 43627              False  ...               False              False
#
#        race_black  race_hispanic  race_white  default_yes  housing_yes  \
# 0           False          False        True        False        False
# 1           False          False        True        False        False
# 2           False           True       False        False        False
# 3           False          False       False        False        False
# 4           False          False        True        False        False
# ...           ...            ...         ...          ...          ...
# 43623       False          False        True        False         True
# 43624       False           True       False        False         True
# 43625       False          False        True        False         True
# 43626       False          False        True        False         True
# 43627       False          False        True        False         True
#
#        contact_telephone  contact_unknown  gender_m
# 0                  False             True      True
# 1                  False            False      True
# 2                  False            False      True
# 3                  False             True      True
# 4                  False            False     False
# ...                  ...              ...       ...
# 43623              False             True     False
# 43624              False            False     False
# 43625              False            False      True
# 43626              False             True      True
# 43627              False             True      True
#
# [43628 rows x 28 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Include your table for the 10 values of k you tried and the corresponding accuracies.

accuracy_results = {}

# Replace x with your desired range values, explain what is happening in this loop
for k in range(1, 23, 2):  
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train, y_train)
    accuracy = knn_model.score(X_test, y_test)
    accuracy_results[k] = accuracy
print(accuracy_results)
# Out:
# {1: 0.8589273435709375, 3: 0.8766903506761403, 5: 0.8795553518221407, 7: 0.8802429520971808, 9: 0.8827641531056613, 11: 0.8823057529223012, 13: 0.881274352509741, 15: 0.8805867522347008, 17: 0.8807013522805409, 19: 0.8805867522347008, 21: 0.8803575521430208}

# %%
#graph of accuracy vs k values
plt.figure(figsize=(10, 6))
plt.plot(list(accuracy_results.keys()), list(accuracy_results.values()), marker='o')
plt.title('KNN Accuracy vs K Values')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.xticks(list(accuracy_results.keys()))
plt.grid()
plt.show()

# %%
# using the hyperparameter k that gave the best accuracy, rerun the model and generate 
# predictions on the test set. Explain why you choose this k value.
best_k = 9  # Replace 'xx' with the best k value found
knn_model = KNeighborsClassifier(n_neighbors=best_k)
knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_test)

# %% [markdown]
# ## Value: Evaluation and Protected Classes

# %%
# create a confusion matrix for your model's predictions. 
# What does the confusion matrix tell you about your model's performance?
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Confusion Matrix')
plt.show()
print(data.columns)
# Out:
# Index(['age', 'balance', 'duration', 'contactndays', 'signed up',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_married', 'marital_single', 'education_secondary',
#        'education_tertiary', 'education_unknown', 'race_black',
#        'race_hispanic', 'race_white', 'default_yes', 'housing_yes',
#        'contact_telephone', 'contact_unknown', 'gender_m'],
#       dtype='object')

# %%
#We already have a model above using KNN so we can use the results to compute fairness metrics

# Compute fairness metrics using Fairlearn

my_metrics = {
    'true positive rate' : true_positive_rate,
    'false positive rate' : false_positive_rate,
    'selection rate' : selection_rate,
    'count' : count
}
# Construct a MetricFrame for race
mf_race = MetricFrame(
    metrics=my_metrics,
    y_true=y_test,
    y_pred=y_pred,
    sensitive_features=X_test["race_white"]  # Replace with your first protected class
)

# Construct a MetricFrame for gender
mf_gender = MetricFrame(
    metrics=my_metrics,
    y_true=y_test,
    y_pred=y_pred,
    sensitive_features=X_test["gender_m"]  # Replace second protected class 
)

# %%
mf_race.by_group #What do the results show? Change the mf_race with each subgroup and report the findings. This means
# you should run this cell multiple times, once for each of the levels in the race variable.
# Out:
#             true positive rate  false positive rate  selection rate   count
# race_white
# False                 0.086436             0.009908        0.018755  6505.0
# True                  0.067376             0.008252        0.015759  2221.0

# %%
mf_gender.by_group #What do the results show? There's only two groups here so we don't need to change anything. 
# in the metric frame.
# Out:
#           true positive rate  false positive rate  selection rate   count
# gender_m
# False               0.073874             0.010537        0.018616  4351.0
# True                0.089770             0.008470        0.017371  4375.0

# %%
# Derived fairness metrics. Be sure you understand the scale and meaning of these. Here we are calculating the 
# two fairness ratios using the gender_m feature, which is bi-variate. What do the results show, is the model more or 
# less fair with this grouping?

dpr_gender = fairlearn.metrics.demographic_parity_ratio(y_test, y_pred, sensitive_features=X_test['gender_m'])
print("Demographic Parity ratio:\t", dpr_gender)

eodds_gender = fairlearn.metrics.equalized_odds_ratio(y_test, y_pred, sensitive_features=X_test['gender_m'])
print("Equalized Odds ratio:\t\t", eodds_gender)
# Out:
# Demographic Parity ratio:	 0.9331245149911817
# Equalized Odds ratio:		 0.8038244353182752

# %%
# Derived fairness metrics. Be sure you understand the scale and meaning of these. Here we are calculating the 
# the same features above only using a filtered search to pull in all the possibilities of features
# starting with "race". What do the results show, is the model more or less fair with this grouping?

dpr_race = fairlearn.metrics.demographic_parity_ratio(y_test, y_pred, sensitive_features=X_test.filter(regex="race.*"))
print("Demographic Parity ratio:\t", dpr_race)

eodds_race = fairlearn.metrics.equalized_odds_ratio(y_test, y_pred, sensitive_features=X_test.filter(regex="race.*"))
print("Equalized Odds ratio:\t\t", eodds_race)
# Out:
# Demographic Parity ratio:	 0.7515133323327831
# Equalized Odds ratio:		 0.6497772061187927

# %%
#Optional code to add, commit, and push changes to your GitHub repository
# !git add .
# !git commit -m "Insert Message Here" # This will commit your changes to git. 
# !git push # This will push your changes to back to your remote repository on GitHub.
# Out:
# [main 4c1a52c] Insert Message Here
#  2 files changed, 976 insertions(+), 83 deletions(-)
#  create mode 100644 ds1001_final/notebooks/scatterplot.png
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 489.63 KiB | 13.23 MiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/malaikaGirma/ds1001_final
#    dc46059..4c1a52c  main -> main
